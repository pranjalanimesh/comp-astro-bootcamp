# %%
# Data Manipulation libraries
import pandas as pd
print(f'pandas: {pd.__version__}')
import numpy as np
print(f'numpy: {np.__version__}')

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15,20)
# Out:
# pandas: 1.4.3
# numpy: 1.23.1

# %%
colnames=['F275W X','F275W Y','F275W cal mag','F275W photometric RMS','F275W Quality-fit param','F275W Sharp param','F275W found','F275W well measured',
               'F336W cal mag','F336W photometric RMS','F336W Quality-fit param','F336W Sharp param','F336W found','F336W well measured',
               'F438W cal mag','F438W photometric RMS','F438W Quality-fit param','F438W Sharp param','F438W found','F438W well measured',
               'F606W cal mag','F606W photometric RMS','F606W Quality-fit param','F606W Sharp param','F606W found','F606W well measured',
               'F814W cal mag','F814W photometric RMS','F814W Quality-fit param','F814W Sharp param','F814W found','F814W well measured',
               'Membership probability','Right Ascention','Declination','Id no.','Iteration']
startrek = pd.read_csv("hlsp_hugs_hst_wfc3-uvis-acs-wfc_ngc2808_multi_v1_catalog-meth1.txt", names=colnames , header=None,sep = '\s+')
startrek.head()
# startrek.info()
# Out:
#      F275W X    F275W Y  F275W cal mag  F275W photometric RMS  \
# 0  4106.5630  1413.5459       -99.9999                99.9999
# 1  4094.2563  1447.0254       -99.9999                99.9999
# 2  4125.7759  1467.5098       -99.9999                99.9999
# 3  4225.4785  1498.3099       -99.9999                99.9999
# 4  4290.4419  1519.3839       -99.9999                99.9999
#
#    F275W Quality-fit param  F275W Sharp param  F275W found  \
# 0                      0.0             9.9999            0
# 1                      0.0             9.9999            0
# 2                      0.0             9.9999            0
# 3                      0.0             9.9999            0
# 4                      0.0             9.9999            0
#
#    F275W well measured  F336W cal mag  F336W photometric RMS  ...  \
# 0                    0       -99.9999                99.9999  ...
# 1                    0       -99.9999                99.9999  ...
# ...

# %%
del_arr=[]
for i in range(len(startrek)):
    if startrek["F275W cal mag"][i]<-80 or startrek["F275W cal mag"][i]-startrek['F336W cal mag'][i]>100:
        del_arr.append(i)
startrek.drop(del_arr,inplace=True)

# %%
plt.rcParams["figure.figsize"] = (20,15)
ax = plt.axes()
ax.set_facecolor("black")
plt.scatter(startrek["F275W cal mag"]-startrek['F336W cal mag'],startrek["F275W cal mag"],s=0.5,color='white')

plt.title("NGC2808")
plt.xlabel("mF275W - mF336W")
plt.ylabel("mF275W")
# plt.figure(figsize=(25,15))
plt.show()

# %% [markdown]
#  -----------------------------------------------------------------------------------------------------------------
#
#                                                    NGC2808 CATALOG
#
#  -----------------------------------------------------------------------------------------------------------------
#
#
#   When you use this catalog in any published work,
#   please cite these papers:
#   Nardiello et al. (2018)
#   Piotto et al. 2015, AJ, 149, 91
#
#   -----------------------------------------------------------------------------------------------------------------
#
#   DATASET: GO-10775 (PI:Sarajedini), GO-12605 (PI:Piotto)
#   Photometric Method: 1
#
#   -----------------------------------------------------------------------------------------------------------------
#
# 1. (X,Y) stellar position in a reference system where the cluster center is in (5000,5000)
# 2. (X,Y) stellar position in a reference system where the cluster center is in (5000,5000)
# 3. F275W calibrated magnitude
# 4. F275W photometric RMS
# 5. F275W quality-fit parameter
# 6. F275W sharp parameter
# 7. Number of F275W exposures the source is found in [99: saturated star]
# 8. Number of F275W exposures the source is well measured [99: saturated star]
# 9. F336W calibrated magnitude
# 10. F336W photometric RMS
# 11. F336W quality-fit parameter
# 12. F336W sharp parameter
# 13. Number of F336W exposures the source is found in [99: saturated star]
# 14. Number of F336W exposures the source is well measured [99: saturated star]
# 15. F438W calibrated magnitude
# 16. F438W photometric RMS
# 17. F438W quality-fit parameter
# 18. F438W sharp parameter
# 19. Number of F438W exposures the source is found in [99: saturated star]
# 20. Number of F438W exposures the source is well measured [99: saturated star]
# 21. F606W calibrated magnitude
# 22. F606W photometric RMS
# 23. F606W quality-fit parameter
# 24. F606W sharp parameter
# 25. Number of F606W exposures the source is found in [99: saturated star]
# 26. Number of F606W exposures the source is well measured [99: saturated star]
# 27. F814W calibrated magnitude
# 28. F814W photometric RMS
# 29. F814W quality-fit parameter
# 30. F814W sharp parameter
# 31. Number of F814W exposures the source is found in [99: saturated star]
# 32. Number of F814W exposures the source is well measured [99: saturated star]
# 33. Membership Probability [-1.0: not available]
# 34. Right ascension (J2000, epoch 2015.0) and Declination (J2000, epoch J2015.0) of the star, astrometrized using Gaia DR1 (Lindegren et al. 2016)
# 35. Right ascension (J2000, epoch 2015.0) and Declination (J2000, epoch J2015.0) of the star, astrometrized using Gaia DR1 (Lindegren et al. 2016)
# 36. Identification number of the star
# 37. Iteration the star was found
#           1-5: found in F606W & F814W images
#             6: found in F438W  images
#             7: found in F336W  images
#             8: found in F275W  images
#   -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Magnitude Systems
#
# Magnitude, in astronomy, measure of the brightness of a star or other celestial body. The brighter the object, the lower the number assigned as a magnitude. In ancient times, stars were ranked in six magnitude classes, the first magnitude class containing the brightest stars. In 1850 the English astronomer Norman Robert Pogson proposed the system presently in use. One magnitude is defined as a ratio of brightness of 2.512 times; e.g., a star of magnitude 5.0 is 2.512 times as bright as one of magnitude 6.0. Thus, a difference of five magnitudes corresponds to a brightness ratio of 100 to 1. After standardization and assignment of the zero point, the brightest class was found to contain too great a range of luminosities, and negative magnitudes were introduced to spread the range.
#
# Apparent magnitude is the brightness of an object as it appears to an observer on Earth. The Sun’s apparent magnitude is −26.7, that of the full Moon is about −11, and that of the bright star Sirius, −1.5. The faintest objects visible through the Hubble Space Telescope are of (approximately) apparent magnitude 30. Absolute magnitude is the brightness an object would exhibit if viewed from a distance of 10 parsecs (32.6 light-years). The Sun’s absolute magnitude is 4.8.

# %% [markdown]
# ### Colour Index
# Colour index, in astronomy, the difference between two measurements of the magnitude (brightness on a logarithmic scale) of a star made at different wavelengths, the value found at the longer wavelength being subtracted from that found at the shorter. Usually the two wavelengths are the blue (B) and the visual (V) as defined in the UBV system.The index is a measure of a star’s colour, an indication of its temperature, and a fairly crude description of the distribution of its radiated energy through the electromagnetic spectrum. The zero point of the colour index scale in the UBV system is chosen such that stars that have a surface temperature of 7,400 K and that are white in colour, such as Vega, have a colour index of zero. Hot, blue stars have negative colour indices, as they radiate most strongly and therefore have numerically lower magnitudes at short wavelengths, and those of cool, red stars are positive. The colour index of a star is increased by the passage of its light through interstellar matter; the amount by which it exceeds the normal value for its spectral type is called the colour excess.
# Stars can also be considered as blackbodies.
#
# T = 4600K(1/(0.92(B-V)+1.7) + 1/(0.92(B-V)+0.62))
